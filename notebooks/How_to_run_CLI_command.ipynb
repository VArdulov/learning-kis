# %% [markdown]
# # How to Train a Koopman Invariant Subspace Model (KIS)
# **By: Victor Ardulov**

# %%
# !python ../train.py --help
# Out:
# usage: train.py [-h] [--name NAME] [--data-path DATA_PATH] [--epochs EPOCHS]
#                 [--num-batches NUM_BATCHES] [--gpu]
#                 [--intermediate-observable INTERMEDIATE_OBSERVABLE]
#                 [--save-model] [--save-training-plot] [--max-lag MAX_LAG]
#                 [--state-space STATE_SPACE] [--alpha ALPHA]
#                 [--learning-rate LEARNING_RATE]
#                 [--validation-data-path VALIDATION_DATA_PATH]
#
# Learning Koopman Invariant Subspace (Now with PyTorch!)
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --name NAME, -n NAME  name of experiment
#   --data-path DATA_PATH
#                         time-series data to model
#   --epochs EPOCHS, -e EPOCHS
#                         number of epochs to train for
#   --num-batches NUM_BATCHES, -b NUM_BATCHES
#                         how many batchs for break the data up into
#   --gpu                 use a GPU or no
# ...

# %%
# !python ../train.py -p -n example -e 100 -v ../val.npy --data-path ../train.npy
# Out:
# Loading training data from ../train.npy
# Loaded a dataset with dimension: (10000, 1)
# Loading validation data from ../val.npy
# WARNING:root:Overwriting intermediate_observable dimension from -1 to 1
# epoch : 1/100, loss = 73.185593
# 	val-loss  = 66.509949
# epoch : 2/100, loss = 69.586929
# 	val-loss  = 66.194344
# epoch : 3/100, loss = 68.983994
# 	val-loss  = 65.851807
# epoch : 4/100, loss = 68.577026
# 	val-loss  = 65.523064
# epoch : 5/100, loss = 68.208748
# 	val-loss  = 65.201378
# epoch : 6/100, loss = 67.853554
# 	val-loss  = 64.882721
# epoch : 7/100, loss = 67.497780
# 	val-loss  = 64.560577
# epoch : 8/100, loss = 67.145020
# 	val-loss  = 64.229103
# epoch : 9/100, loss = 66.789352
# 	val-loss  = 63.906315
# epoch : 10/100, loss = 66.427704
# 	val-loss  = 63.577660
# epoch : 11/100, loss = 66.061707
# 	val-loss  = 63.221127
# epoch : 12/100, loss = 65.689056
# 	val-loss  = 62.882179
# epoch : 13/100, loss = 65.309692
# 	val-loss  = 62.516308
# ...

# %% [markdown]
# ![](example-training-loss.png)
